# %% [markdown]
# **Result**
#
#
# There is no outlier
# The data is clean

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/Stores.csv")
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df.Store_Sales.describe()
# Out:
# count       896.000000
# mean      59351.305804
# std       17190.741895
# min       14920.000000
# 25%       46530.000000
# 50%       58605.000000
# 75%       71872.500000
# max      116320.000000
# Name: Store_Sales, dtype: float64

# %%
sns.histplot(df.Store_Sales);

# %%
mean=df.Store_Sales.mean()
mean
# Out:
# 59351.30580357143

# %%
std=df.Store_Sales.std()
std
# Out:
# 17190.741894878294

# %%
sorted_data=sorted(df.Store_Sales)

# %%
q1,q3=np.percentile(df.Store_Sales,[25,75])
q1,q3
# Out:
# (46530.0, 71872.5)

# %%
IQR=q3-q1
IQR
# Out:
# 25342.5

# %%
left_fence=q1-1.5*IQR
right_fence=q3+1.5*IQR
left_fence,right_fence
# Out:
# (8516.25, 109886.25)

# %%
outlier=df[(i<left_fence) & (i>right_fence)]
outlier
# Out:
# Empty DataFrame
# Columns: [Store ID , Store_Area, Items_Available, Daily_Customer_Count, Store_Sales]
# Index: []

# %%
i= df.Store_Sales

# %%
no_outlier=df[(i>left_fence) & (i<right_fence)]
no_outlier
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [895 rows x 5 columns]

# %%
sns.histplot(no_outlier.Store_Sales)

# %%
sns.boxplot(no_outlier.Store_Sales)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
